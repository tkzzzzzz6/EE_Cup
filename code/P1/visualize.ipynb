# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os
print(os.path.exists('..\..\data/中国光伏电站数据集（ChinaPV）_样例数据/中国光伏电站数据集（ChinaPV）(2015年)_样例数据.shp'))

gdf = gpd.read_file('..\..\data\中国光伏电站数据集（ChinaPV）_样例数据\中国光伏电站数据集（ChinaPV）(2015年)_样例数据.shp')
gdf.plot()
plt.show()
# Out:
# True
